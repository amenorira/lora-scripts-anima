# %% [markdown]
# # lora-scripts-anima
#
# SD LoRA Training Web UI — 基于 kohya-ss/sd-scripts
#
# 云 GPU 平台（AutoDL 等）一键启动：运行下方代码单元格，访问输出的公网 URL 即可打开训练界面。
#
# Cloud GPU (AutoDL etc.) Quick Start: run the code cell below, then open the public URL to access the training UI.

# %% [markdown]
# ### Run | 运行

# %%
import sys
# !export HF_HOME=huggingface && $sys.executable gui.py --host 0.0.0.0

# %% [markdown]
# ## Update | 更新

# %% [markdown]
# ### Github

# %%
# !git pull

# %% [markdown]
# ### 国内镜像加速

# %%
# !export GIT_CONFIG_GLOBAL=./assets/gitconfig-cn && export GIT_TERMINAL_PROMPT=false && git pull
